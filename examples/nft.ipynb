# %% [markdown]
# # NFTs

# %%
import sys
from datetime import datetime, timedelta

import keyring

sys.path.append('../')

from pycgapi import CoinGeckoAPI

# %%
# Fetch the API key securely using keyring
api_key = keyring.get_password('coingecko', 'analyst_api_key')

# Initialize the ContractData class with the fetched API key
cg = CoinGeckoAPI(api_key, pro_api=True)

# %% [markdown]
# ## /nfts/list
# https://docs.coingecko.com/reference/nfts-list

# %%
# Example usage of nfts_supported
nfts_list = cg.nft.nfts_supported(order='market_cap_usd_desc')
print(nfts_list.head())
# Out:
#                                                         contract_address  \
# id
# space-id-bnb                  0xe3b1d32e43ce8d658368e2cbff95d57ef39be8a6
# polychain-monsters-bnb-chain  0x85f0e02cb992aa1f9f47112f815f519ef1a59e2d
# playbux-early-bird-quest      0xc2a19349d5f451071c3085b90f531d19f190ff21
# yuliorigingenone              0x735c4a681f1649f5eee8aac871aa1d89ff056217
# cryptopunks                   0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB
#
#                                                         name  \
# id
# space-id-bnb                                 SPACE ID - .bnb
# polychain-monsters-bnb-chain  Polychain Monsters | BNB Chain
# playbux-early-bird-quest            Playbux Early Bird Quest
# yuliorigingenone                            YuliOriginGenOne
# cryptopunks                                      CryptoPunks
#
#                                 asset_platform_id symbol
# id
# space-id-bnb                  binance-smart-chain    SID
# polychain-monsters-bnb-chain  binance-smart-chain  PMONC
# playbux-early-bird-quest      binance-smart-chain    PBN
# yuliorigingenone              binance-smart-chain   YOG1
# cryptopunks                              ethereum   PUNK

# %% [markdown]
# ## /nfts/{id}
# https://docs.coingecko.com/reference/nfts-id

# %%
# Example usage of nft_collection_info
nft_collection_cryptopunks = cg.nft.nft_collection_info(nft_id='cryptopunks')
nft_collection_cryptopunks
# Out:
#                                        contract_address asset_platform_id  \
# id
# cryptopunks  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB          ethereum
#
#                     name symbol  \
# id
# cryptopunks  CryptoPunks   PUNK
#
#                                                          image  \
# id
# cryptopunks  {'small': 'https://assets.coingecko.com/nft_co...
#
#                                                    description  \
# id
# cryptopunks  <h3 dir="ltr">What Is the CryptoPunks NFT Coll...
#
#             native_currency native_currency_symbol  \
# id
# cryptopunks        ethereum                    ETH
#
#                                            floor_price  \
# id
# cryptopunks  {'native_currency': 39.69, 'usd': 124598}
#
#                                                  market_cap  ...  \
# id                                                           ...
# cryptopunks  {'native_currency': 396662, 'usd': 1245227520}  ...
#
#             one_day_sales_24h_percentage_change  one_day_average_sale_price  \
# id
# cryptopunks                           33.333333                      40.425
#
#             one_day_average_sale_price_24h_percentage_change  \
# id
# cryptopunks                                        -9.455726
#
#                                                          links  \
# id
# cryptopunks  {'homepage': 'https://cryptopunks.app/', 'twit...
#
#                               floor_price_7d_percentage_change  \
# id
# cryptopunks  {'usd': 5.9341850037029, 'native_currency': 1....
#
#                              floor_price_14d_percentage_change  \
# id
# cryptopunks  {'usd': -11.701961035960853, 'native_currency'...
#
#                              floor_price_30d_percentage_change  \
# id
# cryptopunks  {'usd': -28.343490744366022, 'native_currency'...
#
#                              floor_price_60d_percentage_change  \
# id
# cryptopunks  {'usd': -26.227460618426086, 'native_currency'...
#
#                               floor_price_1y_percentage_change  \
# id
# cryptopunks  {'usd': 45.27710166570402, 'native_currency': ...
#
#                                                      explorers
# id
# cryptopunks  [{'name': 'Etherscan', 'link': 'https://ethers...
#
# [1 rows x 30 columns]

# %%
# Example usage of nft_collections_info
nft_ids = ['cryptopunks', 'bored-ape-yacht-club']
collections_info = cg.nft.nft_collections_info(nft_ids=nft_ids)
collections_info
# Out:
#                                                 contract_address  \
# id
# cryptopunks           0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB
# bored-ape-yacht-club                                         NaN
#
#                      asset_platform_id         name symbol  \
# id
# cryptopunks                   ethereum  CryptoPunks   PUNK
# bored-ape-yacht-club               NaN          NaN    NaN
#
#                                                                   image  \
# id
# cryptopunks           {'small': 'https://assets.coingecko.com/nft_co...
# bored-ape-yacht-club                                                NaN
#
#                                                             description  \
# id
# cryptopunks           <h3 dir="ltr">What Is the CryptoPunks NFT Coll...
# bored-ape-yacht-club                                                NaN
#
#                      native_currency native_currency_symbol  \
# id
# cryptopunks                 ethereum                    ETH
# bored-ape-yacht-club             NaN                    NaN
#
#                                                     floor_price  \
# id
# cryptopunks           {'native_currency': 39.69, 'usd': 124598}
# bored-ape-yacht-club                                        NaN
#
#                                                           market_cap  ...  \
# id                                                                    ...
# cryptopunks           {'native_currency': 396662, 'usd': 1245227520}  ...
# bored-ape-yacht-club                                             NaN  ...
#
#                      one_day_sales_24h_percentage_change  \
# id
# cryptopunks                                          NaN
# bored-ape-yacht-club                          -78.378378
#
#                       one_day_average_sale_price  \
# id
# cryptopunks                                  NaN
# bored-ape-yacht-club                     12.2186
#
#                      one_day_average_sale_price_24h_percentage_change  \
# id
# cryptopunks                                                       NaN
# bored-ape-yacht-club                                         2.229202
#
#                                                                   links  \
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  {'homepage': 'http://www.boredapeyachtclub.com...
#
#                                        floor_price_7d_percentage_change  \
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  {'usd': 7.437640197703193, 'native_currency': ...
#
#                                       floor_price_14d_percentage_change  \
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  {'usd': -7.713482976692686, 'native_currency':...
#
#                                       floor_price_30d_percentage_change  \
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  {'usd': -23.19002242536417, 'native_currency':...
#
#                                       floor_price_60d_percentage_change  \
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  {'usd': -42.39258589413477, 'native_currency':...
#
#                                        floor_price_1y_percentage_change  \
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  {'usd': -57.708756394941254, 'native_currency'...
#
#                                                               explorers
# id
# cryptopunks                                                         NaN
# bored-ape-yacht-club  [{'name': 'Etherscan', 'link': 'https://ethers...
#
# [2 rows x 60 columns]

# %% [markdown]
# ## nfts/{asset_platform_id}/contract/{contract_address}
# https://docs.coingecko.com/reference/nfts-contract-address

# %%
nft_collection_data_by_contract = cg.nft.nft_collection_info(
    asset_platform_id='ethereum', 
    contract_address='0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d'
)
nft_collection_data_by_contract
# Out:
#                                                 contract_address  \
# id
# bored-ape-yacht-club  0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d
#
#                      asset_platform_id                  name symbol  \
# id
# bored-ape-yacht-club          ethereum  Bored Ape Yacht Club   BAYC
#
#                                                                   image  \
# id
# bored-ape-yacht-club  {'small': 'https://assets.coingecko.com/nft_co...
#
#                                                             description  \
# id
# bored-ape-yacht-club  <h3>What Is the Bored Ape Yacht Club NFT Colle...
#
#                      native_currency native_currency_symbol  \
# id
# bored-ape-yacht-club        ethereum                    ETH
#
#                                                    floor_price  \
# id
# bored-ape-yacht-club  {'native_currency': 12.02, 'usd': 37742}
#
#                                                          market_cap  ...  \
# id                                                                   ...
# bored-ape-yacht-club  {'native_currency': 120176, 'usd': 377346681}  ...
#
#                      one_day_sales_24h_percentage_change  \
# id
# bored-ape-yacht-club                          -78.378378
#
#                       one_day_average_sale_price  \
# id
# bored-ape-yacht-club                     12.2186
#
#                      one_day_average_sale_price_24h_percentage_change  \
# id
# bored-ape-yacht-club                                         2.229202
#
#                                                                   links  \
# id
# bored-ape-yacht-club  {'homepage': 'http://www.boredapeyachtclub.com...
#
#                                        floor_price_7d_percentage_change  \
# id
# bored-ape-yacht-club  {'usd': 7.437640197703193, 'native_currency': ...
#
#                                       floor_price_14d_percentage_change  \
# id
# bored-ape-yacht-club  {'usd': -7.713482976692686, 'native_currency':...
#
#                                       floor_price_30d_percentage_change  \
# id
# bored-ape-yacht-club  {'usd': -23.19002242536417, 'native_currency':...
#
#                                       floor_price_60d_percentage_change  \
# id
# bored-ape-yacht-club  {'usd': -42.39258589413477, 'native_currency':...
#
#                                        floor_price_1y_percentage_change  \
# id
# bored-ape-yacht-club  {'usd': -57.708756394941254, 'native_currency'...
#
#                                                               explorers
# id
# bored-ape-yacht-club  [{'name': 'Etherscan', 'link': 'https://ethers...
#
# [1 rows x 30 columns]

# %% [markdown]
# ## nfts/markets
# https://docs.coingecko.com/reference/nfts-markets

# %%
# Fetch NFT market data
nft_market_data = cg.nft.nft_market_data(
    asset_platform_id='ethereum',
    order='market_cap_usd_desc',
    per_page=50,
    page=1
)

# Display the first few rows of the fetched data
print('Available Fields: {}'.format(sorted(nft_market_data.columns)))
# Out:
# Available Fields: ['asset_platform_id', 'contract_address', 'description', 'floor_price', 'floor_price_24h_percentage_change', 'floor_price_in_usd_24h_percentage_change', 'image', 'market_cap', 'market_cap_24h_percentage_change', 'name', 'native_currency', 'native_currency_symbol', 'number_of_unique_addresses', 'number_of_unique_addresses_24h_percentage_change', 'one_day_average_sale_price', 'one_day_average_sale_price_24h_percentage_change', 'one_day_sales', 'one_day_sales_24h_percentage_change', 'symbol', 'total_supply', 'volume_24h', 'volume_24h_percentage_change', 'volume_in_usd_24h_percentage_change']

# %% [markdown]
# ## nfts/{id}/market_chart
# https://docs.coingecko.com/reference/nfts-id-market-chart

# %%
# Example call to fetch historical data for a specific NFT
nft_historical_by_id = cg.nft.nft_historical_data(
    nft_id='bored-ape-yacht-club',
    days=30
)

# Display the results
print(nft_historical_by_id.head())
# Out:
#                      floor_price_usd  floor_price_native  h24_volume_usd  \
# timestamp
# 2024-03-23 00:05:16     47777.272522           14.344000    2.160758e+06
# 2024-03-24 00:05:17     45762.829181           13.699797    2.190449e+06
# 2024-03-25 00:05:17     46292.270359           13.408000    5.533064e+06
# 2024-03-26 00:05:16     48346.835252           13.470000    2.225932e+06
# 2024-03-27 00:05:15     48760.044655           13.587000    3.676397e+06
#
#                      h24_volume_native  market_cap_usd  market_cap_native
# timestamp
# 2024-03-23 00:05:16         648.716800    4.776772e+08      143411.312000
# 2024-03-24 00:05:17         655.744251    4.575368e+08      136970.570306
# 2024-03-25 00:05:17        1602.585500    4.628301e+08      134053.184000
# 2024-03-26 00:05:16         620.170898    4.833717e+08      134673.060000
# 2024-03-27 00:05:15        1024.429000    4.875029e+08      135842.826000

# %% [markdown]
# ## nfts/{asset_platform_id}/contract/{contract_address}/market_chart
# https://docs.coingecko.com/reference/nfts-contract-address-market-chart

# %%
# Example call to fetch historical data for a specific NFT
nft_historical_by_contract_address = cg.nft.nft_historical_data(
    asset_platform_id='ethereum', 
    contract_address='0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d',
    days=30
)

# Display the results
print(nft_historical_by_contract_address.head())
# Out:
#                      floor_price_usd  floor_price_native  h24_volume_usd  \
# timestamp
# 2024-03-23 00:05:16     47777.272522           14.344000    2.160758e+06
# 2024-03-24 00:05:17     45762.829181           13.699797    2.190449e+06
# 2024-03-25 00:05:17     46292.270359           13.408000    5.533064e+06
# 2024-03-26 00:05:16     48346.835252           13.470000    2.225932e+06
# 2024-03-27 00:05:15     48760.044655           13.587000    3.676397e+06
#
#                      h24_volume_native  market_cap_usd  market_cap_native
# timestamp
# 2024-03-23 00:05:16         648.716800    4.776772e+08      143411.312000
# 2024-03-24 00:05:17         655.744251    4.575368e+08      136970.570306
# 2024-03-25 00:05:17        1602.585500    4.628301e+08      134053.184000
# 2024-03-26 00:05:16         620.170898    4.833717e+08      134673.060000
# 2024-03-27 00:05:15        1024.429000    4.875029e+08      135842.826000

# %% [markdown]
# ## nfts/{id}/tickers
# https://docs.coingecko.com/reference/nfts-id-tickers

# %%
# Fetch market tickers for the specified NFT
market_tickers = cg.nft.nft_market_tickers(nft_id='bored-ape-yacht-club')
print("Market Tickers for the specified NFT:")
print(market_tickers.head())
# Out:
# Market Tickers for the specified NFT:
#    floor_price_in_native_currency  h24_volume_in_native_currency  \
# 0                           12.02                          72.21
# 1                           12.69                          25.54
# 2                           15.80                           0.00
# 3                           15.80                           0.00
#
#   native_currency native_currency_symbol                updated_at  \
# 0        ethereum                    ETH  2024-04-20T23:00:33.787Z
# 1        ethereum                    ETH  2024-04-20T23:00:33.886Z
# 2        ethereum                    ETH  2024-04-20T23:00:33.978Z
# 3        ethereum                    ETH  2024-04-21T01:00:23.075Z
#
#   nft_marketplace_id       name  \
# 0               blur       Blur
# 1            opensea    OpenSea
# 2               x2y2       X2Y2
# 3          looksrare  LooksRare
#
#                                                image  \
# 0  https://assets.coingecko.com/nft_marketplaces/...
# 1  https://assets.coingecko.com/nft_marketplaces/...
# 2  https://assets.coingecko.com/nft_marketplaces/...
# 3  https://assets.coingecko.com/nft_marketplaces/...
#
#                                   nft_collection_url
# 0       https://blur.io/collection/boredapeyachtclub
# 1    https://opensea.io/collection/boredapeyachtclub
# 2  https://x2y2.io/collection/0xbc4ca0eda7647a8ab...
# 3  https://looksrare.org/collections/0xbc4ca0eda7...

# %% [markdown]
# ## Close Session

# %%
cg.end_session()
# Out:
# 'Session closed successfully.'
