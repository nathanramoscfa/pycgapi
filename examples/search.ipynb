# %% [markdown]
# # search

# %%
import sys
sys.path.append('..')  # This adds the parent directory to the Python path

# %%
import keyring
from coingeckoapi import CoinGeckoAPI

# %%
api_key = keyring.get_password('coingecko', 'analyst_api_key')

# %%
api = CoinGeckoAPI(api_key, pro_api=True)
status = api.status_check()
print("API Server Status:", status)
# Out:
# API Server Status: {'gecko_says': '(V3) To the Moon!'}

# %% [markdown]
# ## /search

# %%
search_results = api.search_coingecko(query='solana')
search_results.keys()
# Out:
# dict_keys(['coins', 'exchanges', 'icos', 'categories', 'nfts'])

# %%
search_results['coins']
# Out:
#                         id                                 name  \
# 0                   solana                               Solana
# 1      green-satoshi-token  STEPN Green Satoshi Token on Solana
# 2               solanacorn                           Solanacorn
# 3        kitty-coin-solana                    Kitty Coin Solana
# 4            oxbull-solana                        Oxbull Solana
# 5   solana-ecosystem-index               Solana Ecosystem Index
# 6             kitty-solana                         Kitty Solana
# 7                solanaape                            SolanaApe
# 8               solanapepe                           SolanaPepe
# 9               solana-gun                           Solana Gun
# 10              solana-inu                           Solana Inu
# 11              solana-nut                           Solana Nut
# 12             solanaprime                          SolanaPrime
# 13             wolf-solana                          WOLF SOLANA
# 14            solana-beach                         Solana Beach
# 15             solana-shib                         Solana Shib
# 16           noka-solana-a                        Noka Solana A
# 17          pepe-on-solana                       Pepe on Solana
# 18            rally-solana                       Rally (Solana)
# 19          wolf-on-solana                       Wolf On Solana
# 20          wrapped-solana                       Wrapped Solana
# 21          chad-on-solana                       Chad On Solana
# 22         jimmy-on-solana                      Jimmy on Solana
# 23         wagmi-on-solana                      WAGMI On Solana
# 24         k-pop-on-solana                      K-Pop on Solana
#
#                 api_symbol   symbol  market_cap_rank  \
# 0                   solana      SOL              5.0
# 1      green-satoshi-token  GST-SOL           1106.0
# 2               solanacorn     CORN           2500.0
# 3        kitty-coin-solana    KITTY           3275.0
# 4            oxbull-solana      OXS           3654.0
# 5   solana-ecosystem-index     SOLI           3759.0
# 6             kitty-solana    KITTY           3918.0
# 7                solanaape     SAPE              NaN
# 8               solanapepe    SPEPE              NaN
# 9               solana-gun   SOLGUN              NaN
# 10              solana-inu      INU              NaN
# 11              solana-nut   SOLNUT              NaN
# 12             solanaprime    PRIME              NaN
# 13             wolf-solana     WOLF              NaN
# 14            solana-beach   SOLANA              NaN
# 15             solana-shib    SSHIB              NaN
# 16           noka-solana-a     NOKA              NaN
# 17          pepe-on-solana     PEPE              NaN
# 18            rally-solana     SRLY              NaN
# 19          wolf-on-solana     WOLF              NaN
# 20          wrapped-solana      SOL              NaN
# 21          chad-on-solana     CHAD              NaN
# 22         jimmy-on-solana    JIMMY              NaN
# 23         wagmi-on-solana    WAGMI              NaN
# 24         k-pop-on-solana     KPOP              NaN
#
#                                                 thumb  \
# 0   https://assets.coingecko.com/coins/images/4128...
# 1   https://assets.coingecko.com/coins/images/2184...
# 2   https://assets.coingecko.com/coins/images/3310...
# 3   https://assets.coingecko.com/coins/images/2081...
# 4   https://assets.coingecko.com/coins/images/1730...
# 5   https://assets.coingecko.com/coins/images/2355...
# 6   https://assets.coingecko.com/coins/images/2031...
# 7   https://assets.coingecko.com/coins/images/3419...
# 8                                   missing_thumb.png
# 9   https://assets.coingecko.com/coins/images/3387...
# 10  https://assets.coingecko.com/coins/images/2002...
# 11  https://assets.coingecko.com/coins/images/2196...
# 12  https://assets.coingecko.com/coins/images/2591...
# 13  https://assets.coingecko.com/coins/images/3212...
# 14  https://assets.coingecko.com/coins/images/3392...
# 15  https://assets.coingecko.com/coins/images/3356...
# 16  https://assets.coingecko.com/coins/images/3427...
# 17  https://assets.coingecko.com/coins/images/3331...
# 18  https://assets.coingecko.com/coins/images/2323...
# 19  https://assets.coingecko.com/coins/images/3371...
# 20  https://assets.coingecko.com/coins/images/2162...
# 21  https://assets.coingecko.com/coins/images/3273...
# 22  https://assets.coingecko.com/coins/images/3388...
# 23  https://assets.coingecko.com/coins/images/2106...
# 24                                  missing_thumb.png
#
#                                                 large
# 0   https://assets.coingecko.com/coins/images/4128...
# 1   https://assets.coingecko.com/coins/images/2184...
# 2   https://assets.coingecko.com/coins/images/3310...
# 3   https://assets.coingecko.com/coins/images/2081...
# 4   https://assets.coingecko.com/coins/images/1730...
# 5   https://assets.coingecko.com/coins/images/2355...
# 6   https://assets.coingecko.com/coins/images/2031...
# 7   https://assets.coingecko.com/coins/images/3419...
# 8                                   missing_large.png
# 9   https://assets.coingecko.com/coins/images/3387...
# 10  https://assets.coingecko.com/coins/images/2002...
# 11  https://assets.coingecko.com/coins/images/2196...
# 12  https://assets.coingecko.com/coins/images/2591...
# 13  https://assets.coingecko.com/coins/images/3212...
# 14  https://assets.coingecko.com/coins/images/3392...
# 15  https://assets.coingecko.com/coins/images/3356...
# 16  https://assets.coingecko.com/coins/images/3427...
# 17  https://assets.coingecko.com/coins/images/3331...
# 18  https://assets.coingecko.com/coins/images/2323...
# 19  https://assets.coingecko.com/coins/images/3371...
# 20  https://assets.coingecko.com/coins/images/2162...
# 21  https://assets.coingecko.com/coins/images/3273...
# 22  https://assets.coingecko.com/coins/images/3388...
# 23  https://assets.coingecko.com/coins/images/2106...
# 24                                  missing_large.png

# %%
search_results['exchanges']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
search_results['icos']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
search_results['categories']
# Out:
#      id               name
# 0    97   Solana Ecosystem
# 1    97   Solana Ecosystem
# 2    97   Solana Ecosystem
# 3    97   Solana Ecosystem
# 4    97   Solana Ecosystem
# 5    97   Solana Ecosystem
# 6    97   Solana Ecosystem
# 7    97   Solana Ecosystem
# 8   251  Solana Meme Coins
# 9    97   Solana Ecosystem
# 10   97   Solana Ecosystem
# 11   97   Solana Ecosystem
# 12   97   Solana Ecosystem
# 13   97   Solana Ecosystem
# 14   97   Solana Ecosystem
# 15   97   Solana Ecosystem
# 16   97   Solana Ecosystem
# 17   97   Solana Ecosystem
# 18   97   Solana Ecosystem
# 19   97   Solana Ecosystem
# 20   97   Solana Ecosystem
# 21   97   Solana Ecosystem
# 22   97   Solana Ecosystem
# 23   97   Solana Ecosystem
# 24   97   Solana Ecosystem
# 25   97   Solana Ecosystem
# 26   97   Solana Ecosystem
# 27   97   Solana Ecosystem
# 28   97   Solana Ecosystem
# 29   97   Solana Ecosystem
# 30   97   Solana Ecosystem
# 31   97   Solana Ecosystem
# 32   97   Solana Ecosystem
# 33   97   Solana Ecosystem
# 34   97   Solana Ecosystem

# %%
search_results['nfts']
# Out:
#                        id                    name              symbol  \
# 0            y00ts-solana          y00ts (Solana)         Y00TSREVEAL
# 1   bored-ape-solana-club   Bored Ape Solana Club  BOREDAPESOLANACLUB
# 2           degods-solana         DeGods (Solana)                DGOD
# 3  solana-monkey-business  Solana Monkey Business                 SMB
# 4    solana-monke-rejects    Solana Monke Rejects                 SMR
#
#                                                thumb
# 0  https://assets.coingecko.com/nft_contracts/ima...
# 1  https://assets.coingecko.com/nft_contracts/ima...
# 2  https://assets.coingecko.com/nft_contracts/ima...
# 3  https://assets.coingecko.com/nft_contracts/ima...
# 4  https://assets.coingecko.com/nft_contracts/ima...

# %%
api.end_session()
# Out:
# 'Session closed successfully.'
