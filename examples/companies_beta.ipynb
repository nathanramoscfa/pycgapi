# %% [markdown]
# # companies (beta)

# %%
import sys
sys.path.append('..')  # This adds the parent directory to the Python path

# %%
import keyring
from coingeckoapi import CoinGeckoAPI

# %%
api_key = keyring.get_password('coingecko', 'analyst_api_key')

# %%
api = CoinGeckoAPI(api_key, pro_api=True)
status = api.status_check()
print("API Server Status:", status)
# Out:
# API Server Status: {'gecko_says': '(V3) To the Moon!'}

# %% [markdown]
# ## /companies/public_treasury/{coin_id}

# %%
public_companies_holdings = api.companies_holdings(coin_id='bitcoin')  # Bitcoin or Ethereum only
public_companies_holdings
# Out:
#                                 name         symbol country  total_holdings  \
# 0                 MicroStrategy Inc.    NASDAQ:MSTR      US          158245
# 1          Marathon Digital Holdings    NASDAQ:MARA      US           13286
# 2            Galaxy Digital Holdings      TSE: GLXY      US           12545
# 3                        Tesla, Inc.    NASDAQ:TSLA      US           10500
# 4               Coinbase Global, Inc    NASDAQ:COIN      US            9182
# 5                  Hut 8 Mining Corp     NASDAQ:HUT      CA            8289
# 6                         Block Inc.        NYSE:SQ      US            8027
# 7                Riot Platforms, Inc    NASDAQ:RIOT      US            7265
# 8                    Hive Blockchain    NASDAQ:HIVE      CA            2332
# 9                       NEXON Co Ltd       TYO:3659      JP            1717
# 10                   CleanSpark Inc.    NASDAQ:CLSK      US            1677
# 11               Exodus Movement Inc   EXOD:OTCMKTS      US            1516
# 12                         Meitu Inc       HKG:1357      HK             940
# 13                  Bit Digital, Inc    NASDAQ:BTBT      US             677
# 14               NFT Investments PLC       AQSE:NFT      GB             517
# 15     DMG Blockchain Solutions Inc.  OTCMKTS:DMGGF      CA             509
# 16                  Bitfarms Limited    NASDAQ:BITF      US             479
# 17                     Cipher Mining    NASDAQ:CIFR      US             404
# 18          BIGG Digital Assets Inc.      CNSX:BIGG      CA             283
# 19      Neptune Digital Assets Corp.     TSXV: DASH      CA             250
# 20  Advanced Bitcoin Technologies AG         ABT:GR      DE             228
# 21                          DigitalX        ASX:DCC      AU             150
# 22                        FRMO Corp.   OTCMKTS:FRMO      US             143
# 23                 The Brooker Group      BKK:BROOK      TH             122
# 24            LQwD Technologies Corp      TSXV:LQWD      CA             113
# 25           Cypherpunk Holdings Inc       CSE:HODL      CA              69
# 26                         Mogo Inc.    NASDAQ:MOGO      CA              18
# 27                   Core Scientific    CORZ:NASDAQ      US              11
#
#     total_entry_value_usd  total_current_value_usd  percentage_of_total_supply
# 0              4680000000               6899692499                       0.754
# 1               189087000                579287273                       0.063
# 2                       0                546978687                       0.060
# 3               336000000                457813967                       0.050
# 4               207783800                400347414                       0.044
# 5                       0                361411426                       0.039
# 6               220000000                349987877                       0.038
# 7                       0                316763663                       0.035
# 8                       0                101678302                       0.011
# 9                99974042                 74863483                       0.008
# 10                      0                 73119430                       0.008
# 11               23163000                 66099616                       0.007
# 12               49500000                 40985250                       0.004
# 13                      0                 29518100                       0.003
# 14                8505363                 22541887                       0.002
# 15                      0                 22193077                       0.002
# 16                      0                 20885037                       0.002
# 17                      0                 17614937                       0.002
# 18                2690387                 12339176                       0.001
# 19                      0                 10900332                       0.001
# 20                2117978                  9941103                       0.001
# 21                 610350                  6540199                       0.001
# 22                      0                  6234990                       0.001
# 23                6600000                  5319362                       0.001
# 24                4360275                  4926950                       0.001
# 25                1910000                  3008491                       0.000
# 26                 595494                   784823                       0.000
# 27                      0                   479614                       0.000

# %%
api.end_session()
# Out:
# 'Session closed successfully.'
