# %% [markdown]
# # trending

# %%
import sys
sys.path.append('..')  # This adds the parent directory to the Python path

# %%
import keyring
from coingeckoapi import CoinGeckoAPI

# %%
api_key = keyring.get_password('coingecko', 'analyst_api_key')

# %%
api = CoinGeckoAPI(api_key, pro_api=True)
status = api.status_check()
print("API Server Status:", status)
# Out:
# API Server Status: {'gecko_says': '(V3) To the Moon!'}

# %% [markdown]
# ## /search/trending

# %%
trending_search_coins = api.trending_searches()
trending_search_coins
# Out:
#                     id  coin_id           name symbol  market_cap_rank  \
# 0                gamee    14716          GAMEE   GMEE              833
# 1          sei-network    28205            Sei    SEI               51
# 2              shido-2    32070          Shido  SHIDO              554
# 3             celestia    31967       Celestia    TIA               43
# 4             arbitrum    16547       Arbitrum    ARB               40
# 5               solana     4128         Solana    SOL                5
# 6                 myro    32878           Myro  $MYRO              424
# 7             ethereum      279       Ethereum    ETH                2
# 8   injective-protocol    12882      Injective    INJ               29
# 9                 bonk    28600           Bonk   BONK              103
# 10       akash-network    12785  Akash Network    AKT              101
# 11              cosmos     1481     Cosmos Hub   ATOM               25
# 12             bitcoin        1        Bitcoin    BTC                1
# 13              tether      325         Tether   USDT                3
# 14                 sui    26375            Sui    SUI               73
#
#                                                 thumb  \
# 0   https://assets.coingecko.com/coins/images/1471...
# 1   https://assets.coingecko.com/coins/images/2820...
# 2   https://assets.coingecko.com/coins/images/3207...
# 3   https://assets.coingecko.com/coins/images/3196...
# 4   https://assets.coingecko.com/coins/images/1654...
# 5   https://assets.coingecko.com/coins/images/4128...
# 6   https://assets.coingecko.com/coins/images/3287...
# 7   https://assets.coingecko.com/coins/images/279/...
# 8   https://assets.coingecko.com/coins/images/1288...
# 9   https://assets.coingecko.com/coins/images/2860...
# 10  https://assets.coingecko.com/coins/images/1278...
# 11  https://assets.coingecko.com/coins/images/1481...
# 12  https://assets.coingecko.com/coins/images/1/th...
# 13  https://assets.coingecko.com/coins/images/325/...
# 14  https://assets.coingecko.com/coins/images/2637...
#
#                                                 small  \
# 0   https://assets.coingecko.com/coins/images/1471...
# 1   https://assets.coingecko.com/coins/images/2820...
# 2   https://assets.coingecko.com/coins/images/3207...
# 3   https://assets.coingecko.com/coins/images/3196...
# 4   https://assets.coingecko.com/coins/images/1654...
# 5   https://assets.coingecko.com/coins/images/4128...
# 6   https://assets.coingecko.com/coins/images/3287...
# 7   https://assets.coingecko.com/coins/images/279/...
# 8   https://assets.coingecko.com/coins/images/1288...
# 9   https://assets.coingecko.com/coins/images/2860...
# 10  https://assets.coingecko.com/coins/images/1278...
# 11  https://assets.coingecko.com/coins/images/1481...
# 12  https://assets.coingecko.com/coins/images/1/sm...
# 13  https://assets.coingecko.com/coins/images/325/...
# 14  https://assets.coingecko.com/coins/images/2637...
#
#                                                 large           slug  \
# 0   https://assets.coingecko.com/coins/images/1471...          gamee
# 1   https://assets.coingecko.com/coins/images/2820...            sei
# 2   https://assets.coingecko.com/coins/images/3207...          shido
# 3   https://assets.coingecko.com/coins/images/3196...       celestia
# 4   https://assets.coingecko.com/coins/images/1654...       arbitrum
# 5   https://assets.coingecko.com/coins/images/4128...         solana
# 6   https://assets.coingecko.com/coins/images/3287...           myro
# 7   https://assets.coingecko.com/coins/images/279/...       ethereum
# 8   https://assets.coingecko.com/coins/images/1288...      injective
# 9   https://assets.coingecko.com/coins/images/2860...           bonk
# 10  https://assets.coingecko.com/coins/images/1278...  akash-network
# 11  https://assets.coingecko.com/coins/images/1481...     cosmos-hub
# 12  https://assets.coingecko.com/coins/images/1/la...        bitcoin
# 13  https://assets.coingecko.com/coins/images/325/...         tether
# 14  https://assets.coingecko.com/coins/images/2637...            sui
#
#        price_btc  score                                               data
# 0   8.265252e-07      0  {'price': '$0.036037371221', 'price_btc': '0.0...
# 1   1.519550e-05      1  {'price': '$0.662540', 'price_btc': '0.0000151...
# 2   1.253802e-07      2  {'price': '$0.005466707213', 'price_btc': '0.0...
# 3   3.306672e-04      3  {'price': '$14.42', 'price_btc': '0.0003306671...
# 4   3.992936e-05      4  {'price': '$1.74', 'price_btc': '0.00003992936...
# 5   2.140639e-03      5  {'price': '$93.33', 'price_btc': '0.0021406387...
# 6   1.856587e-06      6  {'price': '$0.080963513356', 'price_btc': '0.0...
# 7   5.112300e-02      7  {'price': '$2,229.02', 'price_btc': '0.0511229...
# 8   8.204569e-04      8  {'price': '$35.77', 'price_btc': '0.0008204569...
# 9   2.356770e-10      9  {'price': '$0.000010275767', 'price_btc': '0.0...
# 10  6.557851e-05     10  {'price': '$2.86', 'price_btc': '0.00006557851...
# 11  2.219823e-04     11  {'price': '$9.68', 'price_btc': '0.00022198225...
# 12  1.000000e+00     12  {'price': '$43,591.39', 'price_btc': '1.0', 'p...
# 13  2.294383e-05     13  {'price': '$1.00', 'price_btc': '0.00002294382...
# 14  1.921662e-05     14  {'price': '$0.837865', 'price_btc': '0.0000192...

# %%
api.end_session()
# Out:
# 'Session closed successfully.'
